# %% [markdown]
# # Explore here

# %%
# Your code here
import pandas as pd

df = pd.read_csv('../data/raw/River_Arno.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8217 entries, 0 to 8216
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8217 non-null   object
#  1   Rainfall_Le_Croci          6026 non-null   float64
#  2   Rainfall_Cavallina         6026 non-null   float64
#  3   Rainfall_S_Agata           6026 non-null   float64
#  4   Rainfall_Mangona           6026 non-null   float64
#  5   Rainfall_S_Piero           6026 non-null   float64
#  6   Rainfall_Vernio            4283 non-null   float64
#  7   Rainfall_Stia              1283 non-null   float64
#  8   Rainfall_Consuma           1283 non-null   float64
#  9   Rainfall_Incisa            4568 non-null   float64
#  10  Rainfall_Montevarchi       1647 non-null   float64
#  11  Rainfall_S_Savino          1283 non-null   float64
#  12  Rainfall_Laterina          1283 non-null   float64
#  13  Rainfall_Bibbiena          2378 non-null   float64
#  14  Rainfall_Camaldoli         1283 non-null   float64
#  15  Temperature_Firenze        6192 non-null   float64
#  16  Hydrometry_Nave_di_Rosano  8169 non-null   float64
# dtypes: float64(16), object(1)
# memory usage: 1.1+ MB

# %%
ts = pd.DataFrame()
ts['Date'] = pd.to_datetime(df['Date'], format="%d/%m/%Y")
ts['Hyd']= df['Hydrometry_Nave_di_Rosano']
ts.index = ts['Date']
ts.drop(columns='Date',axis=1, inplace=True)

ts
# Out:
#              Hyd
# Date
# 1998-01-01  1.82
# 1998-01-02  1.94
# 1998-01-03  2.11
# 1998-01-04  1.84
# 1998-01-05  1.88
# ...          ...
# 2020-06-26  1.34
# 2020-06-27  1.21
# 2020-06-28  1.30
# 2020-06-29  1.19
# 2020-06-30  1.30
#
# [8217 rows x 1 columns]

# %%
ts.isnull().sum()
# Out:
# Hyd    48
# dtype: int64

# %%
ts = ts.interpolate(method='linear')
ts.isnull().sum()
# Out:
# Hyd    0
# dtype: int64

# %%
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in /home/vscode/.local/lib/python3.11/site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/vscode/.local/lib/python3.11/site-packages (from statsmodels) (1.24.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/vscode/.local/lib/python3.11/site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/vscode/.local/lib/python3.11/site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in /home/vscode/.local/lib/python3.11/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /home/vscode/.local/lib/python3.11/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomp = seasonal_decompose(ts, period = 365)

trend = decomp.trend
seasonal = decomp.seasonal

import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(data=ts, x = ts.index, y = ts.Hyd,label="Hidrometría")
sns.lineplot(data = trend, label="Tendencia")
sns.lineplot(data=seasonal,label="Estacionalidad")

plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries):
    print("Resultados de la prueba de Dickey-Fuller:")
    dftest = adfuller(timeseries, autolag = "AIC")
    dfoutput = pd.Series(dftest[0:4], index = ["Test Statistic", "p-value", "#Lags Used", "Number of Observations Used"])
    for key,value in dftest[4].items():
        dfoutput["Critical Value (%s)"%key] = value
    return dfoutput

test_stationarity(ts)
# Out:
# Resultados de la prueba de Dickey-Fuller:
# Test Statistic                -7.825536e+00
# p-value                        6.496928e-12
# #Lags Used                     3.700000e+01
# Number of Observations Used    8.179000e+03
# Critical Value (1%)           -3.431150e+00
# Critical Value (5%)           -2.861893e+00
# Critical Value (10%)          -2.566958e+00
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf

plot_acf(ts)

plt.tight_layout()
plt.show()

# %%
from pmdarima import auto_arima

model = auto_arima(ts, seasonal=True, trace=True,m=3)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[3] intercept   : AIC=2137.231, Time=11.98 sec
#  ARIMA(0,1,0)(0,0,0)[3] intercept   : AIC=2914.101, Time=0.57 sec
#  ARIMA(1,1,0)(1,0,0)[3] intercept   : AIC=2816.290, Time=1.43 sec
#  ARIMA(0,1,1)(0,0,1)[3] intercept   : AIC=2796.251, Time=1.99 sec
#  ARIMA(0,1,0)(0,0,0)[3]             : AIC=2912.102, Time=0.30 sec
#  ARIMA(2,1,2)(0,0,1)[3] intercept   : AIC=2110.519, Time=11.99 sec
#  ARIMA(2,1,2)(0,0,0)[3] intercept   : AIC=2108.485, Time=7.16 sec
#  ARIMA(2,1,2)(1,0,0)[3] intercept   : AIC=2110.520, Time=8.59 sec
#  ARIMA(1,1,2)(0,0,0)[3] intercept   : AIC=2106.713, Time=3.93 sec
#  ARIMA(1,1,2)(1,0,0)[3] intercept   : AIC=2108.278, Time=6.74 sec
#  ARIMA(1,1,2)(0,0,1)[3] intercept   : AIC=2108.278, Time=6.81 sec
#  ARIMA(1,1,2)(1,0,1)[3] intercept   : AIC=2110.378, Time=7.98 sec
#  ARIMA(0,1,2)(0,0,0)[3] intercept   : AIC=2534.854, Time=2.56 sec
#  ARIMA(1,1,1)(0,0,0)[3] intercept   : AIC=2247.525, Time=4.13 sec
#  ARIMA(0,1,1)(0,0,0)[3] intercept   : AIC=2912.583, Time=0.83 sec
#  ARIMA(2,1,1)(0,0,0)[3] intercept   : AIC=2112.645, Time=3.44 sec
#  ARIMA(1,1,2)(0,0,0)[3]             : AIC=2104.717, Time=1.33 sec
#  ARIMA(1,1,2)(1,0,0)[3]             : AIC=2106.282, Time=2.09 sec
#  ARIMA(1,1,2)(0,0,1)[3]             : AIC=2106.282, Time=2.15 sec
#  ARIMA(1,1,2)(1,0,1)[3]             : AIC=2108.389, Time=2.43 sec
#  ARIMA(0,1,2)(0,0,0)[3]             : AIC=2532.856, Time=0.50 sec
#  ARIMA(1,1,1)(0,0,0)[3]             : AIC=2245.530, Time=0.94 sec
#  ARIMA(2,1,2)(0,0,0)[3]             : AIC=2106.488, Time=1.22 sec
#  ARIMA(0,1,1)(0,0,0)[3]             : AIC=2910.583, Time=0.91 sec
#  ARIMA(2,1,1)(0,0,0)[3]             : AIC=2110.649, Time=1.19 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[3]
# Total fit time: 93.278 seconds

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 8217
# Model:               SARIMAX(1, 1, 2)   Log Likelihood               -1048.359
# Date:                Fri, 14 Nov 2025   AIC                           2104.717
# Time:                        02:44:04   BIC                           2132.773
# Sample:                    01-01-1998   HQIC                          2114.308
#                          - 06-30-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6222      0.010     64.259      0.000       0.603       0.641
# ma.L1         -0.7225      0.009    -78.190      0.000      -0.741      -0.704
# ma.L2         -0.1780      0.006    -32.090      0.000      -0.189      -0.167
# sigma2         0.0756      0.000    297.728      0.000       0.075       0.076
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            673373.52
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.48   Skew:                             4.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                        46.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
forecast = model.predict(n_periods=365)
forecast
# Out:
# 2020-07-01    1.348385
# 2020-07-02    1.366374
# 2020-07-03    1.377566
# 2020-07-04    1.384529
# 2020-07-05    1.388861
#                 ...
# 2021-06-26    1.395996
# 2021-06-27    1.395996
# 2021-06-28    1.395996
# 2021-06-29    1.395996
# 2021-06-30    1.395996
# Freq: D, Length: 365, dtype: float64

# %%
sns.lineplot(data=ts)
sns.lineplot(data=forecast)

plt.tight_layout()
plt.show()

# %%
# !pip install neuralprophet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting neuralprophet
#   Downloading neuralprophet-0.9.0-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.8/145.8 kB 8.7 MB/s eta 0:00:00
# Collecting captum>=0.6.0 (from neuralprophet)
#   Downloading captum-0.8.0-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 32.4 MB/s eta 0:00:0000:01
# Collecting holidays>=0.41 (from neuralprophet)
#   Downloading holidays-0.84-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.2 MB/s eta 0:00:00
# Collecting kaleido==0.2.1 (from neuralprophet)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.1 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: matplotlib>=3.5.3 in /home/vscode/.local/lib/python3.11/site-packages (from neuralprophet) (3.10.7)
# Collecting numpy<2.0.0,>=1.25.0 (from neuralprophet)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 29.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=2.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from neuralprophet) (2.3.3)
# Collecting plotly>=5.13.1 (from neuralprophet)
#   Downloading plotly-6.4.0-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 46.8 MB/s eta 0:00:00:00:0100:01
# Collecting pytorch-lightning>=2.0.0 (from neuralprophet)
#   Downloading pytorch_lightning-2.5.6-py3-none-any.whl (831 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.6/831.6 kB 36.4 MB/s eta 0:00:00
# Collecting tensorboard>=2.11.2 (from neuralprophet)
#   Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 29.6 MB/s eta 0:00:0000:0100:01
# Collecting torch>=2.0.0 (from neuralprophet)
#   Downloading torch-2.9.1-cp311-cp311-manylinux_2_28_x86_64.whl (899.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 472.9 kB/s eta 0:00:0000:0100:01
# Collecting torchmetrics>=1.0.0 (from neuralprophet)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 41.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from neuralprophet) (4.15.0)
# Requirement already satisfied: packaging in /home/vscode/.local/lib/python3.11/site-packages (from captum>=0.6.0->neuralprophet) (25.0)
# Collecting tqdm (from captum>=0.6.0->neuralprophet)
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /home/vscode/.local/lib/python3.11/site-packages (from holidays>=0.41->neuralprophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/vscode/.local/lib/python3.11/site-packages (from matplotlib>=3.5.3->neuralprophet) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=2.0.0->neuralprophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=2.0.0->neuralprophet) (2025.2)
# Collecting narwhals>=1.15.1 (from plotly>=5.13.1->neuralprophet)
#   Downloading narwhals-2.11.0-py3-none-any.whl (423 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 39.7 MB/s eta 0:00:00
# Collecting PyYAML>5.4 (from pytorch-lightning>=2.0.0->neuralprophet)
#   Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (806 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.6/806.6 kB 35.0 MB/s eta 0:00:00
# Collecting fsspec[http]>=2022.5.0 (from pytorch-lightning>=2.0.0->neuralprophet)
#   Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 kB 28.9 MB/s eta 0:00:00
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning>=2.0.0->neuralprophet)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Collecting absl-py>=0.4 (from tensorboard>=2.11.2->neuralprophet)
#   Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 7.7 MB/s eta 0:00:00
# Collecting grpcio>=1.48.2 (from tensorboard>=2.11.2->neuralprophet)
#   Downloading grpcio-1.76.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 49.3 MB/s eta 0:00:00:00:0100:01
# Collecting markdown>=2.6.8 (from tensorboard>=2.11.2->neuralprophet)
#   Downloading markdown-3.10-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 22.5 MB/s eta 0:00:00
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard>=2.11.2->neuralprophet)
#   Downloading protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.2/323.2 kB 36.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/site-packages (from tensorboard>=2.11.2->neuralprophet) (67.8.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.11.2->neuralprophet)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 32.5 MB/s eta 0:00:0000:0100:01
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.11.2->neuralprophet)
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 33.1 MB/s eta 0:00:00
# Collecting filelock (from torch>=2.0.0->neuralprophet)
#   Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: sympy>=1.13.3 in /home/vscode/.local/lib/python3.11/site-packages (from torch>=2.0.0->neuralprophet) (1.14.0)
# Collecting networkx>=2.5.1 (from torch>=2.0.0->neuralprophet)
#   Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 48.4 MB/s eta 0:00:00:00:01
# Requirement already satisfied: jinja2 in /home/vscode/.local/lib/python3.11/site-packages (from torch>=2.0.0->neuralprophet) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 7.0 MB/s eta 0:00:00:00:0100:01
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 44.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 45.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 893.1 kB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 1.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 3.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 8.1 MB/s eta 0:00:00:00:0100:01
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 2.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 2.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 2.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu12==2.27.5 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 2.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 4.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 19.2 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 14.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch>=2.0.0->neuralprophet)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 45.2 MB/s eta 0:00:00
# Collecting triton==3.5.1 (from torch>=2.0.0->neuralprophet)
#   Downloading triton-3.5.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.4/170.4 MB 3.7 MB/s eta 0:00:0000:0100:01
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet)
#   Downloading aiohttp-3.13.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 44.0 MB/s eta 0:00:00:00:01
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from python-dateutil->holidays>=0.41->neuralprophet) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.0.0->neuralprophet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.11.2->neuralprophet) (3.0.3)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet)
#   Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet)
#   Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 15.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet)
#   Downloading frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (231 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.1/231.1 kB 34.0 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet)
#   Downloading multidict-6.7.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.7/246.7 kB 33.5 MB/s eta 0:00:00
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet)
#   Downloading propcache-0.4.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.0/210.0 kB 9.5 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet)
#   Downloading yarl-1.22.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.8/365.8 kB 40.5 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.0 in /home/vscode/.local/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralprophet) (3.11)
# Installing collected packages: nvidia-cusparselt-cu12, kaleido, werkzeug, triton, tqdm, tensorboard-data-server, PyYAML, protobuf, propcache, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, narwhals, multidict, markdown, lightning-utilities, grpcio, fsspec, frozenlist, filelock, attrs, aiohappyeyeballs, absl-py, yarl, tensorboard, plotly, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, holidays, aiosignal, nvidia-cusolver-cu12, aiohttp, torch, torchmetrics, captum, pytorch-lightning, neuralprophet
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.28.7
#     Uninstalling nvidia-nccl-cu12-2.28.7:
#       Successfully uninstalled nvidia-nccl-cu12-2.28.7
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.2
#     Uninstalling numpy-1.24.2:
#       Successfully uninstalled numpy-1.24.2
# Successfully installed PyYAML-6.0.3 absl-py-2.3.1 aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 attrs-25.4.0 captum-0.8.0 filelock-3.20.0 frozenlist-1.8.0 fsspec-2025.10.0 grpcio-1.76.0 holidays-0.84 kaleido-0.2.1 lightning-utilities-0.15.2 markdown-3.10 multidict-6.7.0 narwhals-2.11.0 networkx-3.5 neuralprophet-0.9.0 numpy-1.26.4 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 plotly-6.4.0 propcache-0.4.1 protobuf-6.33.1 pytorch-lightning-2.5.6 tensorboard-2.20.0 tensorboard-data-server-0.7.2 torch-2.9.1 torchmetrics-1.8.2 tqdm-4.67.1 triton-3.5.1 werkzeug-3.1.3 yarl-1.22.0
#
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
ts_np = ts.reset_index()

ts_np
# Out:
#            Date   Hyd
# 0    1998-01-01  1.82
# 1    1998-01-02  1.94
# 2    1998-01-03  2.11
# 3    1998-01-04  1.84
# 4    1998-01-05  1.88
# ...         ...   ...
# 8212 2020-06-26  1.34
# 8213 2020-06-27  1.21
# 8214 2020-06-28  1.30
# 8215 2020-06-29  1.19
# 8216 2020-06-30  1.30
#
# [8217 rows x 2 columns]

# %%
ts_np.rename(columns={'Date':'ds','Hyd':'y'},inplace=True)

# %%
from neuralprophet import NeuralProphet

m = NeuralProphet()

metrics = m.fit(ts_np,freq="D")

future = m.make_future_dataframe(ts_np,periods=365)

forecast = m.predict(future)

fig_forecast = m.plot(forecast)

plt.show()
# Out:
# Importing plotly failed. Interactive plots will not work.
# Importing plotly failed. Interactive plots will not work.
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:464: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   if df.groupby("ID").apply(lambda x: x.duplicated("ds").any()).any():
#
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.988% of the data.
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 64
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 60
# Training: |          | 0/? [00:00<?, ?it/s]
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (129) is too small than the required number                     for the learning rate finder (247). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/247 [00:00<?, ?it/s]
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 64. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/pytorch_lightning/utilities/data.py:79: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 25. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Training: |          | 0/? [00:00<?, ?it/s]
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.988% of the data.
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.726% of the data.
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.726% of the data.
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:1152: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/df_utils.py:464: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   if df.groupby("ID").apply(lambda x: x.duplicated("ds").any()).any():
#
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/data/process.py:517: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_dropped = df.groupby("ID", group_keys=False).apply(lambda x: x.loc[: last_valid_index[x.name]])
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# ERROR - (NP.plotly.plot) - plotly-resampler is not installed. Please install it to use the resampler.
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/plot_forecast_plotly.py:98: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   fcst = fcst.fillna(value=np.nan)
#
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/plot_forecast_plotly.py:100: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ds = fcst["ds"].dt.to_pydatetime()

# %%
# !pip install plotly-resampler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly-resampler
#   Downloading plotly_resampler-0.11.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 8.1 MB/s eta 0:00:00
# Collecting dash>=2.11.0 (from plotly-resampler)
#   Downloading dash-3.3.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 44.2 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: numpy>=1.24 in /home/vscode/.local/lib/python3.11/site-packages (from plotly-resampler) (1.26.4)
# Collecting orjson<4.0.0,>=3.10.0 (from plotly-resampler)
#   Downloading orjson-3.11.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.2/136.2 kB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1 in /home/vscode/.local/lib/python3.11/site-packages (from plotly-resampler) (2.3.3)
# Requirement already satisfied: plotly<7.0.0,>=5.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from plotly-resampler) (6.4.0)
# Collecting tsdownsample>=0.1.3 (from plotly-resampler)
#   Downloading tsdownsample-0.1.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 38.0 MB/s eta 0:00:00:00:01
# Collecting Flask<3.2,>=1.0.4 (from dash>=2.11.0->plotly-resampler)
#   Downloading flask-3.1.2-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: Werkzeug<3.2 in /home/vscode/.local/lib/python3.11/site-packages (from dash>=2.11.0->plotly-resampler) (3.1.3)
# Collecting importlib-metadata (from dash>=2.11.0->plotly-resampler)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from dash>=2.11.0->plotly-resampler) (4.15.0)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.11/site-packages (from dash>=2.11.0->plotly-resampler) (2.32.5)
# Collecting retrying (from dash>=2.11.0->plotly-resampler)
#   Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: nest-asyncio in /home/vscode/.local/lib/python3.11/site-packages (from dash>=2.11.0->plotly-resampler) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/site-packages (from dash>=2.11.0->plotly-resampler) (67.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=1->plotly-resampler) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=1->plotly-resampler) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.11/site-packages (from pandas>=1->plotly-resampler) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /home/vscode/.local/lib/python3.11/site-packages (from plotly<7.0.0,>=5.5.0->plotly-resampler) (2.11.0)
# Requirement already satisfied: packaging in /home/vscode/.local/lib/python3.11/site-packages (from plotly<7.0.0,>=5.5.0->plotly-resampler) (25.0)
# Collecting blinker>=1.9.0 (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler)
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting click>=8.1.3 (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler)
#   Downloading click-8.3.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 22.2 MB/s eta 0:00:00
# Collecting itsdangerous>=2.2.0 (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /home/vscode/.local/lib/python3.11/site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler) (3.0.3)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1->plotly-resampler) (1.17.0)
# Collecting zipp>=3.20 (from importlib-metadata->dash>=2.11.0->plotly-resampler)
#   Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests->dash>=2.11.0->plotly-resampler) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from requests->dash>=2.11.0->plotly-resampler) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests->dash>=2.11.0->plotly-resampler) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from requests->dash>=2.11.0->plotly-resampler) (2025.11.12)
# Installing collected packages: zipp, tsdownsample, retrying, orjson, itsdangerous, click, blinker, importlib-metadata, Flask, dash, plotly-resampler
# Successfully installed Flask-3.1.2 blinker-1.9.0 click-8.3.0 dash-3.3.0 importlib-metadata-8.7.0 itsdangerous-2.2.0 orjson-3.11.4 plotly-resampler-0.11.0 retrying-1.4.2 tsdownsample-0.1.4.1 zipp-3.23.0
#
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
fig_forecast = m.plot(forecast)
# Out:
# ERROR - (NP.plotly.plot) - plotly-resampler is not installed. Please install it to use the resampler.
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/plot_forecast_plotly.py:98: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
#
# WARNING - (py.warnings._showwarnmsg) - /home/vscode/.local/lib/python3.11/site-packages/neuralprophet/plot_forecast_plotly.py:100: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
forecast

sns.lineplot(data=ts)
sns.lineplot(data=forecast,x='ds',y='yhat1')
# Out:
# <Axes: xlabel='Date', ylabel='yhat1'>

# %% [markdown]
# Conclusión:
#
# La predicción de los proximos 365 días de neuralprohit si sigue la logica de la estacionalidad.
#
# Esto a pesar que no tiene los puntos que se disparan hacia arriba tan claro. Indica como se deberia comportar en promedio.
